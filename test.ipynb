# %%
from ultralytics import  YOLO
from pathlib import Path
number_plate_path = Path('models/number_plated/number_plates_model.pt')
number_plate = YOLO(number_plate_path)
print(number_plate_path)
# Out:
# models/number_plated/number_plates_model.pt

# %%
from ultralytics import YOLO

model = YOLO(number_plate_path)  # Load your trained model
results = model.predict(source='test_video.mp4')

# Optionally print or process results
print(results)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/803) /workspaces/ANPR/test_video.mp4: 384x640 3 licenseplates, 141.2ms
# video 1/1 (frame 2/803) /workspaces/ANPR/test_video.mp4: 384x640 3 licenseplates, 71.4ms
# video 1/1 (frame 3/803) /workspaces/ANPR/test_video.mp4: 384x640 2 licenseplates, 62.1ms
# video 1/1 (frame 4/803) /workspaces/ANPR/test_video.mp4: 384x640 3 licenseplates, 63.4ms
# ...

# %%
# !yolo predict  model = number_plate source = test_video.mp4
# Out:
# /bin/bash: line 1: yolo: command not found
